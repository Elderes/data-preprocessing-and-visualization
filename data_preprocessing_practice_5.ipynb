# %%
import pandas as pd
import numpy as np

# %%
iris = pd.read_csv('/content/drive/MyDrive/Datasets/pandas 2/iris.data', header=None)
nba = pd.read_csv('/content/drive/MyDrive/Datasets/pandas 2/games_details.csv')
sup = pd.read_csv('/content/drive/MyDrive/Datasets/pandas 2/supermarket_sales - Sheet1.csv')
wine = pd.read_csv('/content/drive/MyDrive/Datasets/pandas 2/winemag-data-130k-v2.csv', index_col=0)

header = ['sepal_length', 'sepal_width', 'petal_lenght', 'petal_width', 'species']
iris.columns = header
# Out:
# <ipython-input-3-5eccf16d4b09>:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   nba = pd.read_csv('/content/drive/MyDrive/Datasets/pandas 2/games_details.csv')

# %%
# 1
iris[iris[0] > 1.5]
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# 2
nba[nba['PTS'] > 50]
# Out:
#          GAME_ID     TEAM_ID TEAM_ABBREVIATION      TEAM_CITY  PLAYER_ID  \
# 178     22200471  1610612761               TOR        Toronto    1627783
# 1012    22200444  1610612756               PHX        Phoenix    1626164
# 2040    22200399  1610612755               PHI   Philadelphia     203954
# 3299    22200349  1610612747               LAL    Los Angeles     203076
# 4088    22200321  1610612756               PHX        Phoenix    1626164
# ...          ...         ...               ...            ...        ...
# 613176  21300647  1610612761               TOR        Toronto     203082
# 613353  21300640  1610612752               NYK       New York       2546
# 614609  21300592  1610612760               OKC  Oklahoma City     201142
# 644217  21200853  1610612744               GSW   Golden State     201939
# 650947  21200592  1610612760               OKC  Oklahoma City     201142
#
#             PLAYER_NAME NICKNAME START_POSITION COMMENT    MIN  ...  OREB  \
# ...

# %%
# 3
sup['Date'] = pd.to_datetime(sup['Date'])
sup[sup['Date'] > '2019-01-01']
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# 4
wine[(wine['points'] > 90) & (wine['country'] == 'Italy')]
# Out:
#        country                                        description  \
# 120      Italy  Slightly backward, particularly given the vint...
# 130      Italy  At the first it was quite muted and subdued, b...
# 133      Italy  Einaudi's wines have been improving lately, an...
# 135      Italy  The color is just beginning to show signs of b...
# 158      Italy  Baked plum, Asian spice, vanilla and menthol a...
# ...        ...                                                ...
# 129675   Italy  Aromas of underbrush, leather, mature berry, g...
# 129681   Italy  Ripe black-skinned berry, violet, leather and ...
# 129892   Italy  Classic Sangiovese aromas of red berry, culina...
# 129893   Italy  Aromas of passion fruit, hay and a vegetal not...
# 129929   Italy  This luminous sparkler has a sweet, fruit-forw...
#
#                     designation  points  price  province  \
# 120         Bricco Rocche Prapó      92   70.0  Piedmont
# ...

# %%
# 5
x = iris.loc[iris['petal_width'] < 0.2, 'species'] = 'New_specie'
iris['petal_width'] < 0.2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: petal_width, Length: 150, dtype: bool

# %%
# 6
nba.iloc[:11, :6]
# Out:
#      GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0   22200477  1610612759               SAS  San Antonio    1629641
# 1   22200477  1610612759               SAS  San Antonio    1631110
# 2   22200477  1610612759               SAS  San Antonio    1627751
# 3   22200477  1610612759               SAS  San Antonio    1630170
# 4   22200477  1610612759               SAS  San Antonio    1630200
# 5   22200477  1610612759               SAS  San Antonio    1628380
# 6   22200477  1610612759               SAS  San Antonio     203926
# 7   22200477  1610612759               SAS  San Antonio    1626196
# 8   22200477  1610612759               SAS  San Antonio    1631103
# 9   22200477  1610612759               SAS  San Antonio    1628966
# 10  22200477  1610612759               SAS  San Antonio    1629646
#
#          PLAYER_NAME
# 0     Romeo Langford
# 1      Jeremy Sochan
# 2       Jakob Poeltl
# 3      Devin Vassell
# 4          Tre Jones
# 5       Zach Collins
# ...

# %%
# 7
sup[sup['City'] == 'Yangon']
# Out:
#       Invoice ID Branch    City Customer type  Gender            Product line  \
# 0    750-67-8428      A  Yangon        Member  Female       Health and beauty
# 2    631-41-3108      A  Yangon        Normal    Male      Home and lifestyle
# 3    123-19-1176      A  Yangon        Member    Male       Health and beauty
# 4    373-73-7910      A  Yangon        Normal    Male       Sports and travel
# 6    355-53-5943      A  Yangon        Member  Female  Electronic accessories
# ..           ...    ...     ...           ...     ...                     ...
# 990  886-18-2897      A  Yangon        Normal  Female      Food and beverages
# 992  745-74-0715      A  Yangon        Normal    Male  Electronic accessories
# 997  727-02-1313      A  Yangon        Member    Male      Food and beverages
# 998  347-56-2442      A  Yangon        Normal    Male      Home and lifestyle
# 999  849-09-3807      A  Yangon        Member  Female     Fashion accessories
#
# ...

# %%
# 8
wine.set_index(['country', 'province'])
# Out:
#                                                                   description  \
# country  province
# Italy    Sicily & Sardinia  Aromas include tropical fruit, broom, brimston...
# Portugal Douro              This is ripe and fruity, a wine that is smooth...
# US       Oregon             Tart and snappy, the flavors of lime flesh and...
#          Michigan           Pineapple rind, lemon pith and orange blossom ...
#          Oregon             Much like the regular bottling from 2012, this...
# ...                                                                       ...
# Germany  Mosel              Notes of honeysuckle and cantaloupe sweeten th...
# US       Oregon             Citation is given as much as a decade of bottl...
# France   Alsace             Well-drained gravel soil gives this wine its c...
#          Alsace             A dry style of Pinot Gris, this is crisp with ...
#          Alsace             Big, rich and off-dry, this is powered by inte...
#
# ...

# %%
# 9
iris.loc[(iris['species'] == 'Iris-setosa') & (iris.index % 2 == 0)]
# Out:
#     sepal_length  sepal_width  petal_lenght  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 14           5.8          4.0           1.2          0.2  Iris-setosa
# 16           5.4          3.9           1.3          0.4  Iris-setosa
# 18           5.7          3.8           1.7          0.3  Iris-setosa
# 20           5.4          3.4           1.7          0.2  Iris-setosa
# 22           4.6          3.6           1.0          0.2  Iris-setosa
# 24           4.8          3.4           1.9          0.2  Iris-setosa
# ...

# %%
# 10
nba.set_index('PLAYER_NAME')
# Out:
#                   GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  \
# PLAYER_NAME
# Romeo Langford   22200477  1610612759               SAS  San Antonio
# Jeremy Sochan    22200477  1610612759               SAS  San Antonio
# Jakob Poeltl     22200477  1610612759               SAS  San Antonio
# Devin Vassell    22200477  1610612759               SAS  San Antonio
# Tre Jones        22200477  1610612759               SAS  San Antonio
# ...                   ...         ...               ...          ...
# Jordan Hamilton  11200005  1610612743               DEN       Denver
# Kenneth Faried   11200005  1610612743               DEN       Denver
# Kosta Koufos     11200005  1610612743               DEN       Denver
# Timofey Mozgov   11200005  1610612743               DEN       Denver
# Ty Lawson        11200005  1610612743               DEN       Denver
#
#                  PLAYER_ID NICKNAME START_POSITION COMMENT    MIN  FGM  ...  \
# ...

# %%
# 11
x = pd.to_datetime(sup['Date'])
sup['Date'] = x
sup.info()

feb_19 = sup[sup['Date'].dt.to_period('M') == '2019-02']
feb_19
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
# 12
wine.query("country == 'France' & price < 50")
# Out:
#        country                                        description  \
# 7       France  This dry and restrained wine offers spice in p...
# 9       France  This has great depth of flavor with its fresh ...
# 11      France  This is a dry wine, very spicy, with a tight, ...
# 42      France  This is a festive wine, with soft, ripe fruit ...
# 49      France  Soft and fruity, this is a generous, ripe wine...
# ...        ...                                                ...
# 129951  France  Hugely spicy this rich wine is described as sw...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price    province    region_1  \
# 7                                 NaN      87   24.0      Alsace      Alsace
# ...

# %%
# 13
iris.reset_index(drop=True, inplace=True)
iris.iloc[::10]
# Out:
#      sepal_length  sepal_width  petal_lenght  petal_width          species
# 0             5.1          3.5           1.4          0.2      Iris-setosa
# 10            5.4          3.7           1.5          0.2      Iris-setosa
# 20            5.4          3.4           1.7          0.2      Iris-setosa
# 30            4.8          3.1           1.6          0.2      Iris-setosa
# 40            5.0          3.5           1.3          0.3      Iris-setosa
# 50            7.0          3.2           4.7          1.4  Iris-versicolor
# 60            5.0          2.0           3.5          1.0  Iris-versicolor
# 70            5.9          3.2           4.8          1.8  Iris-versicolor
# 80            5.5          2.4           3.8          1.1  Iris-versicolor
# 90            5.5          2.6           4.4          1.2  Iris-versicolor
# 100           6.3          3.3           6.0          2.5   Iris-virginica
# ...

# %%
# 14
nba.set_index(['TEAM_ABBREVIATION', 'PLAYER_NAME'], inplace=True)
nba.index = nba.index.swaplevel(0, 1)
nba.sort_index(level='PLAYER_NAME')
# Out:
#                                    GAME_ID     TEAM_ID    TEAM_CITY  \
# PLAYER_NAME    TEAM_ABBREVIATION
# A.J. Guyton    DET                10300003  1610612765      Detroit
# A.J. Lawson    ATL                12100016  1610612737      Atlanta
#                ATL                12100004  1610612737      Atlanta
#                MIN                22200341  1610612750    Minnesota
#                MIN                22200317  1610612750    Minnesota
# ...                                    ...         ...          ...
# Zylan Cheatham NOP                11900028  1610612740  New Orleans
#                NOP                11900015  1610612740  New Orleans
#                UTA                22100665  1610612762         Utah
#                UTA                22100653  1610612762         Utah
#                UTA                22100624  1610612762         Utah
#
#                                   PLAYER_ID NICKNAME START_POSITION  \
# PLAYER_NAME    TEAM_ABBREVIATION
# ...

# %%
# 15
sup[(sup['Date'].dt.day_of_week == 5) | (sup['Date'].dt.day_of_week == 6)]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 11   529-56-3974      B   Mandalay        Member    Male
# ..           ...    ...        ...           ...     ...
# 978  156-20-0370      B   Mandalay        Normal  Female
# 980  728-47-9078      C  Naypyitaw        Member    Male
# 992  745-74-0715      A     Yangon        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Data Preparation
ds = pd.read_csv('/content/drive/MyDrive/Datasets/GlobalLandTemperaturesByCountry.csv')
ds['AverageTemperature'].fillna(np.mean(ds['AverageTemperature']), inplace=True)
brazil = ds[ds['Country'] == 'Brazil']
new_column = np.random.random(2181) * 100
brazil.insert(3, 'Precipitation', new_column)

print(brazil.describe())
# Out:
#        AverageTemperature  AverageTemperatureUncertainty  Precipitation
# count         2181.000000                    2164.000000    2181.000000
# mean            24.640750                       0.572940      50.121971
# std              1.177483                       0.411794      28.922070
# min             17.193354                       0.060000       0.092959
# 25%             24.001000                       0.243750      25.260662
# 50%             24.814000                       0.416000      49.666188
# 75%             25.447000                       0.840000      75.093032
# max             27.151000                       3.353000      99.981150

# %%
# Descriptive Data Analysis
for column in ds.columns:
  print(ds[column].describe())
  print()

plt.hist(ds['AverageTemperature'], color='#f5c70f')
plt.title('Average Temperature')
plt.show()
# Out:
# count         577462
# unique          3239
# top       2013-09-01
# freq             243
# Name: dt, dtype: object
#
# count    577462.000000
# mean         17.193354
# std          10.639779
# min         -37.658000
# 25%          10.825000
# 50%          19.822000
# 75%          25.654000
# max          38.842000
# Name: AverageTemperature, dtype: float64
#
# count    545550.000000
# mean          1.019057
# std           1.201930
# min           0.052000
# 25%           0.323000
# 50%           0.571000
# 75%           1.206000
# max          15.003000
# Name: AverageTemperatureUncertainty, dtype: float64
#
# count     577462
# unique       243
# top        Åland
# freq        3239
# Name: Country, dtype: object

# %%
# Temporal Visualizations
steps = 200
plt.plot(brazil['dt'][::steps], brazil['AverageTemperature'][::steps], color='#f5c70f')
plt.xticks(rotation=45)
plt.xlabel('Date')
plt.ylabel('Average Temperature')
plt.title('Temporal Visualization for Brazil')
plt.show()

# Create function to separate by year and month?

# %%
# Comparison and Correlation
steps = 225
plt.bar(brazil['dt'][::steps], brazil['Precipitation'][::steps], color='#f5c70f')
plt.xticks(rotation=45)
plt.xlabel('Date')
plt.ylabel('Precipitation')
plt.title('Bar Visualization for Brazil')
plt.show()

# %%
plt.scatter(brazil['AverageTemperature'], brazil['Precipitation'], color='#f5c70f')
plt.xlabel('Average Temperature')
plt.ylabel('Precipitation')
plt.title('Scatter over average temperature and precipitation in Brazil')
plt.show()

# %%
brazil
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty  \
# 77110  1832-01-01           24.935000                          1.372
# 77111  1832-02-01           24.505000                          1.953
# 77112  1832-03-01           24.617000                          1.359
# 77113  1832-04-01           23.990000                          2.013
# 77114  1832-05-01           23.124000                          1.592
# ...           ...                 ...                            ...
# 79286  2013-05-01           24.906000                          0.236
# 79287  2013-06-01           24.788000                          0.251
# 79288  2013-07-01           24.202000                          0.201
# 79289  2013-08-01           24.736000                          0.247
# 79290  2013-09-01           17.193354                            NaN
#
#        Precipitation Country
# 77110      57.179534  Brazil
# 77111      26.486535  Brazil
# 77112      79.997620  Brazil
# ...

# %%
# Advanced Visualizations
sns.heatmap(brazil.iloc[:, 1:-1][::1000], annot=True, cmap='Wistia')
plt.title('Heatmap of features')
plt.show()

# %%
fig, ax = plt.subplots(1, 2)
ax[0].boxplot(brazil['Precipitation'], labels=['Precipitation'])
ax[1].boxplot(brazil['AverageTemperature'], labels=['Average Temperature'])
plt.show()

# %%
# Linear Regression Analysis

steps = 200
sns.lineplot(x='AverageTemperature', y='Precipitation', data=brazil)
sns.regplot(x='AverageTemperature', y='Precipitation', data=brazil, scatter=False)
plt.ylabel('Precipitation')
plt.xlabel('Average Temperature')
plt.title('Average temperature by precipitation with regression')
plt.show()
